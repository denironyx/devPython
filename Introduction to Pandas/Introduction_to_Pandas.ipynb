# %% [markdown]
# <b><font size="6">01. Introduction to Pandas</font><a class="anchor"><a id='toc'></a></b><br><br>
# This notebook is an introduction to Pandas library. Feel free to complement your knowledge with online tutorials such as:<br>
# https://learn.datacamp.com/courses/data-manipulation-with-pandas <br>
# https://www.edx.org/course/analyzing-data-with-python

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font size="5" color='#20346A'><b>Table of Contents</b></font><a class="anchor" id='toc'></a><br>
#
# - [Data](#first-bullet)
# - [Data Exploration and Understanding](#second-bullet)
# </div>

# %% [markdown]
# # <font color='#BFD72F'>1. Data</font> <a class="anchor" id="first-bullet"></a>
#   [Back to TOC](#toc)

# %% [markdown]
# #### 1) [Company Description and Scope](#section_1)<br>2) [Importing Data](#section_2)

# %% [markdown]
# <a class="anchor" id="section_1"></a>
#
# ## 1.1. Company Description and Scope
#
# Tugas is an on-line Portuguese retailer offering an assortment of goods within 5 major categories:
#
# 1. Clothes
# 2. Housekeeping
# 3. Kitchen
# 4. Small appliances
# 5. Toys
#
# Tugas started a loyalty program 2 years ago. Among other objectives, the program’s aim is to gather Customer information to better drive the marketing efforts.
#
# There is enough historical information to start producing sound knowledge about their customer database. The IT department extracted a file (at customer level) to be used by the analytical team.

# %% [markdown]
# <a class="anchor" id="section_2"></a>
#
# ## 1.2. Importing Data

# %% [markdown]
# **Step 1 -** Connect the google colab notebook with your google drive. Before running the code below, make sure you have this notebook in the folders mentioned in the variable 'path'.<br>

# %%
# connect to local repository
from os import getcwd

path = getcwd()
# Out:
# 'c:\\Users\\Dee\\root\\Projects\\personal_real_projects\\devPython\\Introduction to Pandas'

# %% [markdown]
# **Step 2 -** Import the pandas library and define the alias as 'pd'. <br>

# %%
# Step 2
import pandas as pd

# %% [markdown]
# **Step 3 -** Upload the file `tugas.xlsx`. To accomplish this step, read the excel file `tugas.xlsx` that is located inside of the folder 'data' and save it to the object `data` using the pandas method `pd.read_excel()` <br>

# %%
data = pd.read_excel( 'data/tugas.xlsx')

# %% [markdown]
# Now we are going to take a "look" to the data we just imported. <br><br>
# Sometimes it is handy not to print the whole dataframe and flood your screen with data: <br>
# - When a few lines is enough, you can print only the first 5 lines using the pandas `head()` method. <br>
# - Similarly, we can use the `tail()` method to print the last few lines. <br><br>
#
# **Step 4 -** Use the `head()` method as a way to get an overview of the first five rows of the object `data`

# %%
# Step 4
data.head()
# Out:
#    Unnamed: 0  Custid  Year_Birth Gender   Education Marital_Status  \
# 0           0    1041        1997      F       Basic         Single
# 1           1    1061        1947      F         PhD          Widow
# 2           2    1076        1986      F         PhD        Married
# 3           3    1091        1969      F  Graduation         Single
# 4           4    1094        1964      M         PhD          Widow
#
#    Dependents     Income Dt_Customer  Rcn  Frq      Mnt  Clothes  Kitchen  \
# 0           1   37950.15  2013-08-08   65   14   156.00        6       28
# 1           0  100873.50  2014-05-02    6   29  1331.20       41        2
# 2           1   65426.55  2013-10-21   86   12   153.92       68        1
# 3           1   76444.20  2013-07-09   85   15   229.84       66        6
# 4           1   94752.00  2013-06-11    8   21   624.00       91        0
#
#    SmallAppliances  HouseKeeping  Toys  NetPurchase  CatPurchase  \
# ...

# %% [markdown]
# |Method | Description | Link |
# |-----|-----|----|
# | pandas.DataFrame.head(n) | Return the first n rows (_default n = 5_). |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html)|
# | pandas.DataFrame.tail(n)| Return the last n rows (_default n = 5_).|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html)|

# %% [markdown]
# # <font color='#BFD72F'>2. Data Exploration and Understanding</font> <a class="anchor" id="second-bullet"></a>
#   [Back to TOC](#toc)
#
#
# * [2.1 - The Variables](#variables)
# * [2.2 - Attributes of the Dataset](#attributes)
# * [2.3 - Statistical Information](#statistics)
# * [2.4 - More Exploration](#more_explore)
# * [2.5 - Visualization](#visual)

# %% [markdown]
# <a class="anchor" id="variables"></a>
#
# ### 2.1. The Variables

# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1p7XQndwTjqzrFI4uf2t8aXyRx54TZPiI)

# %% [markdown]
# <a class="anchor" id="attributes"></a>
#
# ## 2.2. Atributes of the Dataset

# %% [markdown]
# ### 2.2.1. The number of rows and columns
#
# Shape is an an attribute in DataFrames that returns a tuple representing the dimensionality of the DataFrame, i.e., the number of rows and columns (number_rows, number_columns). <br>
# We can find the dimensions of the dataset using the pandas DataFrame 'shape' attribute.

# %% [markdown]
# **Step 5** - Check the shape of the dataset `data` using the attribute `shape`

# %%
# Step 5
data.shape
# Out:
# (400, 20)

# %% [markdown]
# We can observe that the dataset contains 400 rows and 20 columns.

# %% [markdown]
# ### 2.2.2. The column labels
#
# To obtain the name of the columns that we are working with, we can call the attribute `columns`.

# %% [markdown]
# **Step 6** - Check the name of columns of `data` dataset using the attribute `columns`

# %%
# Step 6
data.columns
# Out:
# Index(['Unnamed: 0', 'Custid', 'Year_Birth', 'Gender', 'Education',
#        'Marital_Status', 'Dependents', 'Income', 'Dt_Customer', 'Rcn', 'Frq',
#        'Mnt', 'Clothes', 'Kitchen', 'SmallAppliances', 'HouseKeeping', 'Toys',
#        'NetPurchase', 'CatPurchase', 'Recomendation'],
#       dtype='object')

# %% [markdown]
# ### 2.2.3. Get a specific value
#
# To obtain a specific value in a row and column we can use the method `at`.

# %% [markdown]
# **Step 7** - Check the value in `data` dataset in the row 23 and column 'Gender' using the attribute `at`

# %%
# Step 7
data.at[23,'Gender']
# Out:
# 'F'

# %% [markdown]
# |Attribute | Description | Link |
# |-----|-----|----|
# | pandas.DataFrame.shape | Return a tuple representing the dimensionality of the DataFrame. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shape.html)|
# | pandas.DataFrame.columns| Return the column labels of the DataFrame.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.columns.html)|
# | pandas.DataFrame.at| Access a single value for a row/column label pair.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.at.html#pandas.DataFrame.at)|

# %% [markdown]
# <a class="anchor" id="statistics"></a>
#
# ## 2.3. Statistical Information
#
#
#
# One of the first things that we should do when analysing a dataset is to understand the type of data of our variables and if we have missing values. <br>
#
#
# ### 2.3.1. Get the type and non-null values for each variable
# Using the method `info()`, we can get that information.

# %% [markdown]
# **Step 8** - Check the data type of the variables and the non-missing values for each variable in the dataset using the method  `info()`

# %%
# Step 8
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       400 non-null    int64
#  1   Custid           400 non-null    int64
#  2   Year_Birth       400 non-null    int64
#  3   Gender           400 non-null    object
#  4   Education        397 non-null    object
#  5   Marital_Status   399 non-null    object
#  6   Dependents       400 non-null    int64
#  7   Income           385 non-null    float64
#  8   Dt_Customer      400 non-null    datetime64[ns]
#  9   Rcn              400 non-null    int64
#  10  Frq              400 non-null    int64
#  11  Mnt              400 non-null    float64
#  12  Clothes          400 non-null    int64
#  13  Kitchen          400 non-null    int64
#  14  SmallAppliances  400 non-null    int64
#  15  HouseKeeping     400 non-null    int64
# ...

# %% [markdown]
# In this dataset, we can verify that we have:
# - 1 variable as datetime;
# - 2 variables with the type float;
# - 14 variables that are integer;
# - 3 variables that are objects, which is the same as to say categorical variables.
#
# We still can conclude that we have missing values on some of the variables, namely:
# - Education (3 missing values)
# - Marital_Status (1 missing value);
# - Income (15 missing values)

# %% [markdown]
# ### 2.3.2. Get the descriptive statistics for each variable

# %% [markdown]
# The method `describe`:
# - Generates descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values. <br>
# - By default, it will show the count, mean, interquartiles and max for each numerical variable.<br>
# - To have the summary statistics for categorical variables, we should add as a parameter 'include = ['O']'. This will give us the count, the quantity of unique values, the most frequent value and the frequency for the most frequent value.<br>

# %% [markdown]
# **Step 9** - By using the method `describe()`, obtain the descritptive statistics for the numerical data.

# %%
# Step 9
data.describe()

# Get a table transposed
# tugas.describe().T
# Out:
#        Unnamed: 0        Custid   Year_Birth  Dependents         Income  \
# count  400.000000    400.000000   400.000000  400.000000     385.000000
# mean   199.500000   5935.825000  1959.647500    0.495000   87692.882727
# std    115.614301   2897.782067    17.166682    0.500601   29891.432159
# min      0.000000   1041.000000  1937.000000    0.000000   19747.350000
# 25%     99.750000   3343.000000  1945.000000    0.000000   65663.850000
# 50%    199.500000   5782.500000  1953.500000    0.000000   94103.100000
# 75%    299.250000   8519.000000  1974.000000    1.000000  111232.800000
# max    399.000000  10965.000000  1997.000000    1.000000  144204.900000
#
#               Rcn         Frq          Mnt     Clothes     Kitchen  \
# count  400.000000  400.000000   400.000000  400.000000  400.000000
# mean    55.180000   26.690000  1085.102200   51.805000    6.227500
# std     48.311516   13.094563   844.201132   21.660793    6.443177
# ...

# %% [markdown]
# **Step 10** - By using the method `describe(include=['O'])`, obtain the descritptive statistics for the categorical data.

# %%
# Step 10
data.describe(include = ['O'])
# Out:
#        Gender   Education Marital_Status
# count     400         397            399
# unique      3           5              6
# top         F  Graduation        Married
# freq      312         198            141

# %% [markdown]
# ### 2.3.3. Count how many valid values for each variable

# %% [markdown]
# **Step 11** - By using the method `count()`, check how many valid values we have for each of the variables.

# %%
# Step 11
data.count()
# Out:
# Unnamed: 0         400
# Custid             400
# Year_Birth         400
# Gender             400
# Education          397
# Marital_Status     399
# Dependents         400
# Income             385
# Dt_Customer        400
# Rcn                400
# Frq                400
# Mnt                400
# Clothes            400
# Kitchen            400
# SmallAppliances    400
# HouseKeeping       400
# Toys               400
# NetPurchase        400
# CatPurchase        400
# Recomendation      400
# dtype: int64

# %% [markdown]
# We already have saw that the `info()` method gives us similar information. <br>
# But sometimes it could be useful to understand how many valid values we have for a specific variable. Most methods that we apply for the dataset, we can also apply to a specific column.

# %% [markdown]
# **Step 12** - By using the method `count()`, check how many valid values we have for the variable ´Rcn´

# %%
# Step 12
data['Rcn'].count()
# Out:
# 400

# %% [markdown]
# Instead of checking the quantity of valid values for each variable, we can check the number of missing values for each of the variables. To do that, we can use the method `isna()` that will verify if any value that we have in our dataset is null, and join the method `sum()` as a way to count the missing values for each of the variables.

# %% [markdown]
# **Step 13** - By using the methods `isna().sum()`, verify how many missing values do we have for each of the variables in percentage.

# %%
# Step 13
data.isna().sum() / len(data) * 100
# round(data.isna().sum()/len(data)*100,2)
# Out:
# Unnamed: 0         0.00
# Custid             0.00
# Year_Birth         0.00
# Gender             0.00
# Education          0.75
# Marital_Status     0.25
# Dependents         0.00
# Income             3.75
# Dt_Customer        0.00
# Rcn                0.00
# Frq                0.00
# Mnt                0.00
# Clothes            0.00
# Kitchen            0.00
# SmallAppliances    0.00
# HouseKeeping       0.00
# Toys               0.00
# NetPurchase        0.00
# CatPurchase        0.00
# Recomendation      0.00
# dtype: float64

# %% [markdown]
# ### 2.3.4. Check the frequency of each level in categorical variables

# %% [markdown]
# We already know that we have categorical data in our dataset. What if I want to know how many values we have for each level of the categorical data? We can use the method `value_counts()` for that purpose.

# %% [markdown]
# **Step 14** - Use the method `value_counts()` on the variable 'Marital_status' and check the result.

# %%
# Step 14
data['Marital_Status'].value_counts()
# Out:
# Married         141
# Together        114
# Single           70
# Divorced         42
# Widow            28
# BigConfusion      4
# Name: Marital_Status, dtype: int64

# %% [markdown]
# By the results, we can conclude that the majority of our customers is married or together.  <br> Probably, the consumer behaviour of both categories is similar and maybe we should join both categories? We will do this forward - for now we are just exploring the dataset. <br>
#
# On the other hand, it seems that we have one level that does not make sense - the BigConfusion. This type of errors should also be adressed in a future step.

# %% [markdown]
# **Step 15** - Use the method `value_counts()` on the variable 'Education' and check the result.

# %%
# Step 15
data['Education'].value_counts()
# Out:
# Graduation    198
# 2n Cycle       76
# Master         62
# Basic          36
# PhD            25
# Name: Education, dtype: int64

# %% [markdown]
# Maybe having so many different levels for education is not helpful. In a later step, we are going to create a new variable where each customer's education is only identified by having or not higher education.

# %% [markdown]
# **Step 16** - Use the method `value_counts()` on the variable 'Recomendation' and check the result.

# %%
# Step 16
data['Recomendation'].value_counts()
# Out:
# 5    151
# 4     98
# 3     61
# 6     55
# 2     34
# 1      1
# Name: Recomendation, dtype: int64

# %% [markdown]
# During the exploration phase, we should pay attention to all the details, even the smallest ones. <br>
# During the phase of Business needs, and more concretely, during the variables description, it was defined that the 'Recomendation' variable would be on a scale between 1 and 5... so it seems we also have an error in here that should be adressed later.

# %% [markdown]
# The `describe()` method that we saw previously gives all the major descriptive statistics of each of the variables that we are working with. But in some cases, it could be useful to access a specific descriptive statistic of a specific variable, like the mean or mode, the median, the skewness and so on.

# %% [markdown]
# ### 2.3.5. Obtain the mean of one variable

# %% [markdown]
# **Step 17** - Use the method `mean()` on the variable 'Rcn' and check the result.

# %%
# Step 17
data['Rcn'].mean()
# Out:
# 55.18

# %% [markdown]
# This information tells that in average the last time customers visited the store was around 55 days.

# %% [markdown]
# ### 2.3.6. Obtain the median of two or more variables

# %% [markdown]
# **Step 18** - Use the method `median()` on variables 'Rcn' and 'Income' and check the result.

# %%
# Step 18
data[['Rcn','Income']].median()
# Out:
# Rcn          52.0
# Income    94103.1
# dtype: float64

# %% [markdown]
# This information tells that half of the customers did not visit the store for less than or exactly 52 days. It also tells that half of the customers have an income that is higher or exactly 94103.1.

# %% [markdown]
# ### 2.3.7. Obtain the standard deviation for all the variables (numerical ones)

# %% [markdown]
# **Step 19** - Use the method `std()` on the dataset and check the result.

# %%
# Step 19
data.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Unnamed: 0                          115.614301
# Custid                             2897.782067
# Year_Birth                           17.166682
# Dependents                            0.500601
# Income                            29891.432159
# Dt_Customer        197 days 07:34:19.401895644
# Rcn                                  48.311516
# Frq                                  13.094563
# Mnt                                 844.201132
# Clothes                              21.660793
# Kitchen                               6.443177
# SmallAppliances                      12.624488
# HouseKeeping                          6.827188
# Toys                                  6.692752
# ...

# %% [markdown]
# Now we have information on the standard deviations of all columns in the dataset.

# %% [markdown]
# ### 2.3.8. Other methods (Descriptive)

# %% [markdown]
# In similar way, you can apply the methods `skew()` to obtain the skewness, `kurt` to get the kurtosis, `min()` and `max()` to obtain the minimum and maximum values respectively, `var()` to get the variance, `quantile()` to verify the quantiles and `mode()` to detect the most frequent value in a categorical variable. <br>Those are the most used ones, but you have several other methods that you can apply to your dataframe.

# %% [markdown]
# |Method | Description | Link |
# |-----|-----|----|
# | pandas.DataFrame.info() |  Prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html)|
# | pandas.DataFrame.describe()| Generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)|
# | pandas.DataFrame.count() | Count non-NA cells for each column or row. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.count.html)|
# | pandas.DataFrame.isna()| Return a boolean same-sized object indicating if the values are NA.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.isna.html)|
# | pandas.DataFrame.value_counts() |  Return a Series containing counts of unique values. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)|
# | pandas.DataFrame.mean()|  Return the mean of the values for the requested axis. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html)|
# | pandas.DataFrame.median() | Return the median of the values for the requested axis. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.median.html)|
# | pandas.DataFrame.skew()| Return unbiased skew over requested axis Normalized by N-1.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.skew.html)|
# | pandas.DataFrame.kurt() | Return unbiased kurtosis over requested axis using Fisher’s definition of kurtosis (kurtosis of normal == 0.0). Normalized by N-1.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.kurt.html)|
# | pandas.DataFrame.min()| Return the minimum of the values for the requested axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.min.html)|
# | pandas.DataFrame.max() | Return the maximum of the values for the requested axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.max.html)|
# | pandas.DataFrame.std()| Return sample standard deviation over requested axis. Normalized by N-1 by default. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.std.html)|
# | pandas.DataFrame.var()| Return unbiased variance over requested axis. Normalized by N-1 by default. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.var.html)|
# | pandas.DataFrame.quantile()| Return values at the given quantile over requested axis. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.quantile.html)|
# | pandas.DataFrame.mode()| Get the mode(s) of each element along the selected axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mode.html)|
# | pandas.DataFrame.sum()| Return the sum of the values for the requested axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html)|
# | pandas.DataFrame.mad()| Return the mean absolute deviation of the values for the requested axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mad.html)|
# | pandas.DataFrame.abs()| Return a Series/DataFrame with absolute numeric value of each element.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.abs.html)|
# | pandas.DataFrame.prod()| Return the product of the values for the requested axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.prod.html)|
# | pandas.DataFrame.sem()| Return unbiased standard error of the mean over requested axis.Normalized by N-1 by default.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sem.html)|
# | pandas.DataFrame.cumsum()| Return cumulative sum over a DataFrame or Series axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.cumsum.html)|
# | pandas.DataFrame.cumprod()| Return cumulative product over a DataFrame or Series axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.cumprod.html)|
# | pandas.DataFrame.cummax()| Return cumulative maximum over a DataFrame or Series axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.cummax.html)|
# | pandas.DataFrame.cummin()| Return cumulative minimum over a DataFrame or Series axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.cummin.html)|
# |----|----|----|
# |round()|Return number rounded to ndigits precision after the decimal point.|[+ info](https://docs.python.org/3/library/functions.html#round)|
# |pandas.DataFrame.T|Transpose index and columns. Reflect the DataFrame over its main diagonal by writing rows as columns and vice-versa. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.transpose.html)|
# |len()|Return the length (the number of items) of an object.|[+ info](https://docs.python.org/3/library/functions.html#len)|

# %% [markdown]
# <a class="anchor" id="more_explore"></a>
#
# ## 2.4. More Exploration : Summarising, aggregating and grouping data

# %% [markdown]
# ### 2.4.1. The groupby() method

# %% [markdown]
# ##### What is the mean value of Income for the different genders?
# **Step 20** - Using the method `groupby()`, group your data according to `Gender` and get the mean value of the Income variable.

# %%
data.groupby('Gender')['Income'].mean()
# Out:
# Gender
# ?    69639.150000
# F    86877.787500
# M    91074.039759
# Name: Income, dtype: float64

# %% [markdown]
# ##### What is the frequency, the minimum, the maximum and the mean value of year of birth of our customers that have an recomendation level greater than 4?
#
# **Step 21** - Using the method `agg()`, obtain the count, the min, the max and the mean for the variable `Year_Birth` for the onservations where the Recomendation is greater or equal than 4.

# %%
data[data['Recomendation'] >= 4]['Year_Birth'].agg(['count', 'min', 'max', 'mean'])
# Out:
# count     304.000000
# min      1937.000000
# max      1997.000000
# mean     1955.003289
# Name: Year_Birth, dtype: float64

# %% [markdown]
# ### 2.4.2. The query() method

# %% [markdown]
# ##### What are the observations in my dataframe where the Gender is defined as '?' ?
# **Step 22** - Using the `query()` method, get all the observations where `Gender == "?"` from the dataset.

# %%
data.query('Gender == "?"')
# Out:
#      Unnamed: 0  Custid  Year_Birth Gender   Education Marital_Status  \
# 296         296    8426        1951      ?  Graduation         Single
# 340         340    9494        1985      ?  Graduation        Married
#
#      Dependents     Income Dt_Customer  Rcn  Frq      Mnt  Clothes  Kitchen  \
# 296           0  106153.95  2013-07-25   55   41  1791.92       40        8
# 340           1   33124.35  2013-12-04   46    9    24.96       75        3
#
#      SmallAppliances  HouseKeeping  Toys  NetPurchase  CatPurchase  \
# 296               32             6    14           46           54
# 340               20             1     1           60           40
#
#      Recomendation
# 296              5
# 340              5

# %% [markdown]
# |Method | Description | Link |
# |-----|-----|----|
# | pandas.DataFrame.groupby() |  Group DataFrame or Series using a mapper or by a Series of columns.A groupby operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html)|
# | pandas.DataFrame.agg()|Aggregate using one or more operations over the specified axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.agg.html)|
# | pandas.DataFrame.query() | Query the columns of a DataFrame with a boolean expression. |[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html)|
# | pandas.DataFrame.sort_value()| Sort by the values along either axis.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html)|

# %% [markdown]
# <a class="anchor" id="visual"></a>
#
# ## 2.5. Visual Exploration
#
#
# ### Why would I need to learn to visualize data?
# - It is a way to show complex data in a form that is graphical and easy to understand
# - Plots and graphs can be very effective in conveying a clear description of the data especially when disclosing findings to an audience or sharing the data <br><br>
#
# 1. For exploratory analysis
# 2. To communicate data clearly
# 3. To share unbiased representations of data
# 4. Use them to support recommendation to different stakeholders

# %% [markdown]
# ### What is Seaborn?
# Seaborn is a graphical package that provides a high-level interface to Matplotlib, in an easy way. <br>
#
# Seaborn allows to:<br>
# - Using default themes that are aesthetically pleasing;<br>
# - Setting custom colour pallets;<br>
# - Making attractive statistical plots;<br>
# - Easily and flexibly displaying distributions;<br>
# - Visualizing information from matrices and DataFrames.<br>
#
# Seaborn is a complement and not a substitute for Matplotlib.<br>
#
# One of the greatest strengths of seaborn is its diversity of plotting functions. For example, to make a scatter plot, we just need to write one line of code, using the function lmplot().<br>

# %% [markdown]
# ### 2.5.1. Import the needed libraries and the dataset
#
# In order to create visualizations, we need to import some libraries with that specific functionality.
# In this way, we always should import the matplotlib, the basic library in python to create plots.

# %% [markdown]
# **Step 23** - Import matplotlib.pyplot as define as alias the name 'plt'. <br>
# In jupyter notebooks, we should use the command '%matplotlib inline' after importing the library matplotlib as a way to guarantee that the plots will be included in your notebook, next to the code.

# %%
# Step 23
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Step 24** - Import seaborn and define as alias the name 'sns'. <br>

# %%
# Step 24
import seaborn as sns

# %% [markdown]
# Now that we already imported the previous libraries, we are ready to start plotting our data. We are just going to see some examples.

# %% [markdown]
# <a href="https://seaborn.pydata.org/api.html#relational-api">Click here for more information about the different plots in Seaborn </a>

# %% [markdown]
# ### 2.5.2. Histograms
# A histogram is an approximate representation of the distribution of numerical data. It is similar to a Bar Chart, but a histogram groups numbers into ranges. The height of each bar shows how many fall into each range.
#
# And you decide what ranges to use!

# %% [markdown]
# **Step 25** - Using the seaborn method `histplot`, create a new histogram by defining the parameters:
# - `data = data`
# - `x = 'Year_Birth'` <br>

# %%
# Step 25
sns.histplot(data=data, x='Year_Birth')

# %% [markdown]
# ### 2.5.3.  Boxplots
#
# Boxplots can be a useful visualization tool to get an overview of the major descriptive statistics and to check if we are in the presence of outliers. Using seaborn, we can create boxplots using the information of one, two or three different variables.
#
# **Step 26** - Using the seaborn method `boxplot()`, create a univariate plot by defining the parameters:
# - `x = 'HouseKeeping'`
# - `data = data`<br>

# %%
# Step 26
sns.boxplot(x='HouseKeeping', data = data)

# %% [markdown]
# ### 2.5.4.  Scatter plots
# If we want to display the values of two variables, we can use scatterplots. This type of plot can also be useful to verify if two variables are related to each other.

# %% [markdown]
# **Step 27** - Using the seaborn method `scatterplot`, create a new plot by defining the parameters:
# - `x = 'Income'`
# - `y = 'Mnt'`
# - `data = data`<br>

# %%
# Step 27
sns.scatterplot(x = 'Income', y = 'Mnt', data = data)

# %% [markdown]
# We can verify that the higher the Income of a Customer, the more money he spents on our store.

# %% [markdown]
# We can express a third dimension of information in a scatterplot using the parameter `hue`. This will color points taking into account the value of a specific categorical variable.<br>

# %% [markdown]
# **Step 28**  - Using the seaborn method `scatterplot`, create a new plot by defining the parameters:
# - `x = 'Income'`
# - `y = 'Mnt'`
# - `data = 'data'`<br>
# - `hue = 'Recomendation'`

# %%
# Step 28
sns.scatterplot(x = 'Income', y = 'Mnt', hue = 'Recomendation', data = data)

# %% [markdown]
# ### 2.5.5. Countplot
# When we want to show the number of observations in each category we can use the countplot function. This is similar to a histogram over a categorical, rather than quantitative, variable.

# %% [markdown]
# **Step 29** - Using the seaborn method `countplot()`, create a new plot by defining the parameters:
# - `y = 'Marital_Status'`
# - `hue = 'Gender'`
# - `data = 'tugas'`
# - `order = ['Single','Divorced','Widow','Married','Together']`<br>

# %%
# Step 29
sns.countplot(y = 'Marital_Status', hue = 'Gender', data = data,
             order = ['Single','Divorced','Widow','Married','Together'])

# %% [markdown]
# |Library | Method | Description | Link |
# |-----|-----|-----|----|
# | Seaborn |  seaborn.scatterplot() |Draw a scatter plot with possibility of several semantic groupings. |[+ info](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)|
# | Seaborn |  seaborn.boxplot() |Draw a box plot to show distributions with respect to categories.|[+ info](https://seaborn.pydata.org/generated/seaborn.boxplot.html)|
# | Seaborn |  seaborn.countplot() |Show the counts of observations in each categorical bin using bars. |[+ info](https://seaborn.pydata.org/generated/seaborn.countplot.html)|
# | Seaborn |  seaborn.pairplot() |Plot pairwise relationships in a dataset. |[+ info](https://seaborn.pydata.org/generated/seaborn.pairplot.html)|
# | Seaborn |  seaborn.heatmap() |Plot rectangular data as a color-encoded matrix. |[+ info](http://seaborn.pydata.org/generated/seaborn.heatmap.html)|
# |-----|-----|-----|----|
# | Matplotlib | matplotlib.pyplot.ylim() | Get or set the y-limits of the current axes.|[+ info](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.ylim.html)|
# | Matplotlib | matplotlib.pyplot.xlim() | Get or set the x limits of the current axes.|[+ info](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.xlim.html)|
# | Matplotlib | matplotlib.pyplot.xticks() | Get or set the current tick locations and labels of the x-axis..|[+ info](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.xticks.html)|
# | Matplotlib | matplotlib.pyplot.title() | Set a title for the axes.|[+ info](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.title.html)|
# | Matplotlib | matplotlib.pyplot.legend() | Place a legend on the axes.|[+ info](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.legend.html)|
# | Matplotlib | matplotlib.pyplot.xlabel() | Set the label for the x-axis.|[+ info](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.xlabel.html)|
# | Matplotlib | matplotlib.pyplot.figure() | Create a new figure.|[+ info](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.figure.html)|
# | Matplotlib | matplotlib.pyplot.savefig() | Save the current figure.|[+ info](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.savefig.html)|
# |-----|-----|-----|----|
# | Pandas | pandas.DataFrame.copy() | Make a copy of this object’s indices and data.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html)|
# | Pandas | pandas.DataFrame.corr() | Compute pairwise correlation of columns, excluding NA/null values.|[+ info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html)|
